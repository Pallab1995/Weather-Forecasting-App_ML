# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (1.49.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (6.2.0)
# Requirement already satisfied: click<9,>=7.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<26,>=20 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: colorama in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in e:\cv\anaconda\envs\pallab_new_ml\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile my_app.py
import streamlit as st
from datetime import date, timedelta
import requests
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# ------------------- Custom CSS -------------------
st.markdown(
    """
    <style>
    .stApp {
        background: linear-gradient(120deg, #74ebd5, #ACB6E5, #89f7fe, #66a6ff);
        background-size: 400% 400%;
        animation: gradientShift 15s ease infinite;
        font-family: 'Trebuchet MS', sans-serif;
    }

    @keyframes gradientShift {
        0% {background-position: 0% 50%;}
        50% {background-position: 100% 50%;}
        100% {background-position: 0% 50%;}
    }

    .title {
        text-align: center;
        font-size: 50px;
        font-weight: bold;
        color: #FFD700;
        text-shadow: 3px 3px 6px #00000066;
    }

    .subtitle {
        text-align: center;
        font-size: 22px;
        color: #ffffff;
        margin-bottom: 25px;
    }

    /* Make widget labels dark */
    .stSelectbox label, .stDateInput label {
        color: #222 !important;
        font-weight: 600;
        font-size: 18px;
    }

    .card {
        background: rgba(255, 255, 255, 0.15);
        padding: 20px;
        border-radius: 20px;
        color: #fff;
        text-align: center;
        font-size: 20px;
        box-shadow: 0px 8px 25px rgba(0,0,0,0.25);
        backdrop-filter: blur(10px);
        margin-bottom: 20px;
    }
    </style>
    """,
    unsafe_allow_html=True
)


# ------------------- Title -------------------
st.markdown('<div class="title">🌡 Future Temperature Predictor</div>', unsafe_allow_html=True)

# ------------------- API Endpoints -------------------
GEOCODE_URL = "https://geocoding-api.open-meteo.com/v1/search"
HIST_URL = "https://archive-api.open-meteo.com/v1/archive"

# ------------------- Helper Functions -------------------
def geocode_city(name):
    params = {"name": name, "count": 1, "language": "en", "Format": "json"}
    r = requests.get(GEOCODE_URL, params=params, timeout=30)
    r.raise_for_status()
    data = r.json()
    if not data.get('results'):
        raise ValueError(f"Could not geocode city '{name}'. Try a different spelling.")
    res = data['results'][0]
    return {
        'name': res.get('name'),
        'latitude': res['latitude'],
        'longitude': res['longitude'],
        'timezone': res.get('timezone'),
        'country': res.get('country'),
        'admin1': res.get('admin1')
    }

def fetch_history(lat, lon, start_date, end_date, timezone='auto'):
    params = {
        'latitude': lat,
        'longitude': lon,
        'start_date': start_date.isoformat(),
        'end_date': end_date.isoformat(),
        'daily': ['temperature_2m_max', 'temperature_2m_min'],
        'timezone': timezone
    }
    r = requests.get(HIST_URL, params=params, timeout=30)
    r.raise_for_status()
    data = r.json()
    daily = data.get('daily', {})
    if not daily or 'time' not in daily:
        return pd.DataFrame()
    df = pd.DataFrame(daily)
    df['time'] = pd.to_datetime(df['time'])
    df["temp_mean"] = (pd.to_numeric(df["temperature_2m_max"], errors='coerce') +
                       pd.to_numeric(df["temperature_2m_min"], errors='coerce')) / 2.0
    df["date"] = pd.to_datetime(df["time"])
    df = df.dropna(subset=['temp_mean']).reset_index(drop=True)
    return df[["date", "temperature_2m_min", "temperature_2m_max", "temp_mean"]]

def predict_future_temp(hist_df, target_date):
    hist_df["days"] = (hist_df["date"] - hist_df["date"].min()).dt.days
    X = hist_df[["days"]]
    y = hist_df["temp_mean"]
    model = Pipeline([("poly", PolynomialFeatures(degree=3)), ("linear", LinearRegression())])
    model.fit(X, y)
    target_days = (target_date - hist_df["date"].min().date()).days
    pred_temp = model.predict(pd.DataFrame({"days": [target_days]}))[0]
    return pred_temp

# ------------------- UI Elements -------------------
cities = ["Kolkata", "Delhi", "Mumbai", "Chennai", "Bengaluru", "Hyderabad"]
city = st.selectbox("🏙️ Enter a city name in India:", cities)
future_date = st.date_input("📅 Select future date:", date.today() + timedelta(days=1))

# ------------------- Predict Button -------------------
if st.button("🔮 Predict"):
    with st.spinner("Fetching data & predicting temperature..."):
        try:
            place = geocode_city(city)
            lat, lon, tz = place['latitude'], place['longitude'], place['timezone']
            today = date.today()
            start_date = today - timedelta(days=120)
            end_date = today - timedelta(days=1)

            hist_df = fetch_history(lat, lon, start_date, end_date, tz)
            if hist_df.empty:
                st.error("No historical data available.")
            else:
                pred_temp = predict_future_temp(hist_df, future_date)

                # Select image and message based on temperature
                if pred_temp < 20:
                    img_url = "https://img.icons8.com/emoji/96/snowflake.png"
                    msg = "🥶 It's going to be quite chilly!"
                elif pred_temp < 30:
                    img_url = "https://img.icons8.com/emoji/96/sun-behind-cloud.png"
                    msg = "😊 Pleasant weather ahead!"
                else:
                    img_url = "https://img.icons8.com/emoji/96/sun.png"
                    msg = "🔥 It's going to be hot, stay hydrated!"

                st.image(img_url, width=100)

                # Styled result card
                st.markdown(
                    f"""
                    <div class="result-card" style="color:black;">
                        🌍 <b>{city}</b><br>
                        📅 {future_date}<br>
                        🌡️ Predicted Temperature: <b>{pred_temp:.2f}°C</b><br>
                        {msg}
                    </div>
                    """,
                    unsafe_allow_html=True
                )

                # Show historical trend + prediction
                chart_df = hist_df.copy()
                chart_df = chart_df.set_index("date")
                st.line_chart(chart_df["temp_mean"],use_container_width=True, height=250)

                st.markdown(
                     f'<p style="color:black; font-weight:bold;">🔎 Historical trend of mean daily temperature for {city}</p>',
                  unsafe_allow_html=True
                  )
        except Exception as e:
            st.error(f"Error: {str(e)}")
# Out:
# Overwriting my_app.py

# %%
# !pip install streamlit pyngrok    # to use ngrok
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^

# %%
# !pkill streamlit   # use to kill any active streamlit session
# Out:
# 'pkill' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from pyngrok import ngrok

# Paste your authtoken here
ngrok.set_auth_token("31bjRweCKkLeeaqZb8jSJZnDGYb_g6ZowrvMsARpRZjGQp8Y")    # open the account in ngrok and to connect use the auth_token
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 4
#       1 from pyngrok import ngrok
#       3 # Paste your authtoken here
# ----> 4 ngrok.set_auth_token("31bjRweCKkLeeaqZb8jSJZnDGYb_g6ZowrvMsARpRZjGQp8Y")    # open the account in ngrok and to connect use the auth_token
#
# File c:\Users\palla\.virtualenvs\ice_breaker-qNn00m5o\Lib\site-packages\pyngrok\ngrok.py:157, in set_auth_token(token, pyngrok_config)
#     153     pyngrok_config = conf.get_default()
#     155 install_ngrok(pyngrok_config)
# --> 157 process.set_auth_token(pyngrok_config, token)
#
# File c:\Users\palla\.virtualenvs\ice_breaker-qNn00m5o\Lib\site-packages\pyngrok\process.py:200, in set_auth_token(pyngrok_config, token)
#     196 else:
#     197     logger.info(
#     198         f"Updating authtoken for default \"config_path\" of \"ngrok_path\": {pyngrok_config.ngrok_path}")
# --> 200 result = str(subprocess.check_output(start))
#     202 if "Authtoken saved" not in result:
#     203     raise PyngrokNgrokError(f"An error occurred when saving the auth token: {result}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)   1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# OSError: [WinError 225] Operation did not complete successfully because the file contains a virus or potentially unwanted software

# %%
# Start Streamlit in background
get_ipython().system_raw("streamlit run my_app.py &")

# Open ngrok tunnel
public_url = ngrok.connect(8501)
public_url
# Out:
# <NgrokTunnel: "https://2453b7a717f4.ngrok-free.app" -> "http://localhost:8501">
